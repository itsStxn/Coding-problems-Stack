# %% [markdown]
# # Daily Temperatures

# %%
import importlib
import solution as _

importlib.reload(_)
task = _.Solution()

# %% [markdown]
# ## Test 1

# %%
task.carFleet(target = 12, position = [10,8,0,5,3], speed = [2,4,1,1,3])
# Out:
# 3

# %% [markdown]
# ## Test 2

# %%
task.carFleet(target = 10, position = [3], speed = [3])
# Out:
# 1

# %% [markdown]
# ## Test 3

# %%
task.carFleet(target = 100, position = [0,2,4], speed = [4,2,1])
# Out:
# 1
