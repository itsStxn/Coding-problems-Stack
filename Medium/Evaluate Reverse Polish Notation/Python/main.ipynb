# %% [markdown]
# # Evaluate Reverse Polish Notation

# %%
import importlib
import solution as _

importlib.reload(_)
task = _.Solution()

# %% [markdown]
# ## Test 1

# %%
task.evalRPN(tokens = ["2","1","+","3","*"])
# Out:
# 9

# %% [markdown]
# ## Test 2

# %%
task.evalRPN(tokens = ["4","13","5","/","+"])
# Out:
# 6

# %% [markdown]
# ## Test 3

# %%
task.evalRPN(tokens = ["10","6","9","3","+","-11","*","/","*","17","+","5","+"])
# Out:
# 22
