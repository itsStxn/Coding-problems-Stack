# %% [markdown]
# # Daily Temperatures

# %%
import importlib
import solution as _

importlib.reload(_)
task = _.Solution()

# %% [markdown]
# ## Test 1

# %%
task.dailyTemperatures(temperatures = [73,74,75,71,69,72,76,73])
# Out:
# [1, 1, 4, 2, 1, 1, 0, 0]

# %% [markdown]
# ## Test 2

# %%
task.dailyTemperatures(temperatures = [30,40,50,60])
# Out:
# [1, 1, 1, 0]

# %% [markdown]
# ## Test 3

# %%
task.dailyTemperatures(temperatures = [30,60,90])
# Out:
# [1, 1, 0]
