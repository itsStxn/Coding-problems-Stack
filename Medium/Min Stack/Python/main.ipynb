# %% [markdown]
# # Min Stack

# %%
import importlib
import solution as _

importlib.reload(_)
# Out:
# <module 'solution' from 'c:\\Home links\\Personal\\Programming skills\\Coding problems\\Stack\\Medium\\Min Stack\\Python\\solution.py'>

# %% [markdown]
# ## Test

# %%
minStack = _.MinStack()
minStack.push(-2)
minStack.push(0)
minStack.push(-3)
minStack.getMin() # return -3
# Out:
# -3

# %%
minStack.pop()
minStack.top()    # return 0
# Out:
# 0

# %%
minStack.getMin() # return -2
# Out:
# -2
