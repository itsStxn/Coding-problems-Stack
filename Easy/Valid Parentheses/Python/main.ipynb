# %% [markdown]
# # Valid Parentheses

# %%
import importlib
import solution as _

importlib.reload(_)
task = _.Solution()

# %% [markdown]
# ## Test 1

# %%
task.isValid(s = "()")
# Out:
# True

# %% [markdown]
# ## Test 2

# %%
task.isValid(s = "()[]{}")
# Out:
# True

# %% [markdown]
# ## Test 3

# %%
task.isValid(s = "(]")
# Out:
# False

# %% [markdown]
# ## Test 4

# %%
task.isValid(s = "([])")
# Out:
# True

# %% [markdown]
# ## Test 5

# %%
task.isValid(s = "([)]")
# Out:
# False
